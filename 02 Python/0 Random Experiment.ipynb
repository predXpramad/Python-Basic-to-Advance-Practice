# %%
import random
A = [random.randint(10,50) for _ in range(10)]

# %%
A
# Out:
# [33, 41, 23, 20, 21, 49, 22, 34, 19, 31]

# %%
A.extend([5,6,7])

# %%
A.remove(5)

# %%
# Out:
# 4

# %%
# Out:
# 10

# %%
# Out:
# Deleting Radius..
# Radius Deleted!

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 shape.radius
#
# Cell In[39], line 8, in Circle.radius(self)
#       6     @property
#       7     def radius(self):
# ----> 8         return self._radius
#
# AttributeError: 'Circle' object has no attribute '_radius'
